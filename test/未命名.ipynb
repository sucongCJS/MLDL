# %% [markdown]
# - [巨佬Jason Brownlee LSTM实操](https://machinelearningmastery.com/multi-step-time-series-forecasting-long-short-term-memory-networks-python/)
# - [pandas参数说明](https://www.cnblogs.com/datablog/p/6127000.html)

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
# load dataset
series = read_csv('NSE-BSE.csv', header=0, parse_dates=[0], index_col=0, squeeze=True)
# header: 列名的所在那一行索引, 默认是0, 即第一行是列名, 可以是列表
# parse_datas: 是时间列的索引

# summarize first few rows
print(series.head())
# line plot
series.plot()
pyplot.show()
# Out:
#              Open    High    Low    Last   Close  Total Trade Quantity  \
# Date
# 2018-09-28  707.0  707.95  681.0  682.65  683.10              131700.0
# 2018-09-27  716.8  723.50  691.1  697.80  697.15              156222.0
# 2018-09-26  720.0  724.40  709.0  710.00  711.60               71780.0
# 2018-09-25  725.0  725.00  710.5  715.00  718.15               93181.0
# 2018-09-24  725.3  728.00  712.0  721.00  721.90              126374.0
#
#             Turnover (Lacs)
# Date
# 2018-09-28           910.52
# 2018-09-27          1104.25
# 2018-09-26           513.48
# 2018-09-25           668.03
# 2018-09-24           911.15
